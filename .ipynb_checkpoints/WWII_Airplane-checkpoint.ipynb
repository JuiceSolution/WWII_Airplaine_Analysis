# %% [markdown]
# # Practice Using
# # PANDAS - MATPLOTLIB - SEABORN

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd # dealing with datframes
import numpy as np# Fast Math
import matplotlib as plt# Graphing
import seaborn as sns # Prettier Graphing
import os
import random
import sklearn

# %% [markdown]
# # Load and Verify Data

# %%
df = pd.read_csv("ww2aircraft.csv")

# %%
df.head(2)
# Out:
#   Name    PrimaryRole    Manufacturer Country  Number  ActiveSince  LastBuilt  \
# 0  130       Seaplane  Loire Aviation     NaN     NaN          NaN        NaN
# 1  143  Medium Bomber    Avions Amiot  France   138.0       1935.0     1937.0
#
#    Retired    State  Crew Length Wingspan  Height  WingArea  MaxSpeed
# 0      NaN      NaN   NaN    NaN      NaN     NaN       NaN       NaN
# 1   1944.0  Retired   5.0  18.24    24.53    5.68     100.0     295.0

# %% [markdown]
# # Cleaning Null Values

# %%
# Call # of DF Entries
print(type(df[['Country']]))
df[['Country']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             Country
# 0               NaN
# 1            France
# 2             Japan
# 3             Japan
# 4            France
# ..              ...
# 333   United States
# 334  United Kingdom
# 335           Italy
# 336           Italy
# 337           Italy
#
# [338 rows x 1 columns]

# %%
# To clean the df and reasign it to a new df (recomended) use this
print(type(df[['Country']]))
clean_df = df[['Country']].dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# If you need to clean and edit the origional df, you can do so by adding - inplace = True
# df[['Country']].dropna(inplace = True)
# df

# %% [markdown]
# ## Various Descriptave Statistics

# %%
df.describe()
# Out:
#              Number  ActiveSince    LastBuilt      Retired        Crew  \
# count    321.000000   310.000000   270.000000   300.000000  322.000000
# mean    2349.604361  1939.012903  1943.437037  1948.953333    2.909938
# std     4568.322880     3.864178     6.163940     9.280711    2.453549
# min        1.000000  1924.000000  1932.000000  1931.000000    1.000000
# 25%      146.000000  1937.000000  1940.250000  1945.000000    1.000000
# 50%      574.000000  1940.000000  1944.000000  1945.000000    2.000000
# 75%     1984.000000  1942.000000  1945.000000  1952.000000    4.000000
# max    36163.000000  1945.000000  2009.000000  1995.000000   14.000000
#
#            Height    WingArea    MaxSpeed
# count  317.000000  315.000000  322.000000
# mean     4.474767   52.747749  440.968012
# std      3.066930   54.694519  157.400581
# min      1.160000    3.600000  125.000000
# 25%      3.250000   21.910000  325.500000
# 50%      3.890000   32.400000  435.950000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          338 non-null    object
#  1   PrimaryRole   338 non-null    object
#  2   Manufacturer  337 non-null    object
#  3   Country       322 non-null    object
#  4   Number        321 non-null    float64
#  5   ActiveSince   310 non-null    float64
#  6   LastBuilt     270 non-null    float64
#  7   Retired       300 non-null    float64
#  8   State         322 non-null    object
#  9   Crew          322 non-null    float64
#  10  Length        320 non-null    object
#  11  Wingspan      321 non-null    object
#  12  Height        317 non-null    float64
#  13  WingArea      315 non-null    float64
#  14  MaxSpeed      322 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 39.7+ KB

# %% [markdown]
# # Exploratory Data Analasys (EDA)

# %%
# counting unique values
n = pd.unique(df['Country'])
n
# Out:
# array([nan, 'France', 'Japan', 'United States', 'United Kingdom',
#        'Germany', 'Czechoslovakia', 'Italy', 'Russia', 'Australia',
#        'China', 'Netherlands', 'Romania', 'Poland'], dtype=object)

# %% [markdown]
# ----------------

# %% [markdown]
# ## Working with Pandas Series

# %%
# Sum of countries DOES NOT INCLUED Null values or (NaN)
sum(df['Country'].value_counts())
# Out:
# 322

# %%
# Count of countries DOES NOT INCLUED Null values or (NaN)
df['Country'].count()
# Out:
# 322

# %% [markdown]
# ----------------

# %% [markdown]
# ## Prepareing Useful Measurements for Analasys

# %%
# Calling one column returns a Series
df['Country']
# Out:
# 0                 NaN
# 1              France
# 2               Japan
# 3               Japan
# 4              France
#             ...
# 333     United States
# 334    United Kingdom
# 335             Italy
# 336             Italy
# 337             Italy
# Name: Country, Length: 338, dtype: object

# %%
#pandas.core.series.Series - "Series" Is formated like a dictionary and functions similarly
type(Aircraft_per_country)
# Out:
# pandas.core.series.Series

# %%
# arrays are essentially Lists
Aircraft_per_country.values
# Out:
# array([73, 69, 53, 43, 33, 24, 14,  5,  2,  2,  2,  1,  1])

# %%
# Calling a column with 2 [[]] brackets returns a DF instead of a series
df[['Country']]
# Out:
#             Country
# 0               NaN
# 1            France
# 2             Japan
# 3             Japan
# 4            France
# ..              ...
# 333   United States
# 334  United Kingdom
# 335           Italy
# 336           Italy
# 337           Italy
#
# [338 rows x 1 columns]

# %%
# Count values of column
Aircraft_per_country = df['Country'].value_counts()
Aircraft_per_country
# Out:
# United States     73
# Japan             69
# Germany           53
# United Kingdom    43
# Italy             33
# Russia            24
# France            14
# Poland             5
# China              2
# Australia          2
# Netherlands        2
# Czechoslovakia     1
# Romania            1
# Name: Country, dtype: int64

# %%
# index attribute call the labels in order
Aircraft_per_country.index
# Out:
# Index(['United States', 'Japan', 'Germany', 'United Kingdom', 'Italy',
#        'Russia', 'France', 'Poland', 'China', 'Australia', 'Netherlands',
#        'Czechoslovakia', 'Romania'],
#       dtype='object')

# %% [markdown]
# ax = sns.barplot(x="x1", y="y1", data=tips,
#                  palette="Blues_d")

# %% [markdown]
# ----------------

# %% [markdown]
# ## # Seaborn Library barplot

# %%
ax = sns.barplot(x=Aircraft_per_country.index, y=Aircraft_per_country.values, 
                 palette="Blues_d")

# %%
ax = sns.barplot(x=Aircraft_per_country.values, y=Aircraft_per_country.index, 
                 palette="Blues_d")

# %% [markdown]
# ----------------

# %% [markdown]
# ## # .plot is native pandas

# %%
Aircraft_per_country.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
Aircraft_per_country.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ----------------# .plot is native pandas# .plot is native pandas# .plot is native pandas

# %% [markdown]
# ----------------

# %%
Count_of_Craft_type = df['PrimaryRole'].value_counts()

# %%
Count_of_Craft_type
# Out:
# Fighter                    76
# Medium Bomber              43
# Seaplane                   36
# Transport                  25
# Torpedo Bomber             18
# Reconnaissance Aircraft    16
# Prototype Aircraft         15
# Heavy Bomber               15
# Heavy Fighter              14
# Dive Bomber                11
# Light Bomber               11
# Trainer Aircraft           10
# Other                      10
# Ground Attack Aircraft      8
# Jet Fighter                 7
# Biplane Fighter             6
# Glider                      5
# Night Fighter               4
# Assault Drone               2
# Light Observation           2
# Sport Aircraft              1
# Liaison Aircraft            1
# Short-Haul Airliner         1
# Patrol Airship              1
# Name: PrimaryRole, dtype: int64

# %%
df[df["PrimaryRole"] == "Light Bomber"]
# Out:
#              Name   PrimaryRole                                Manufacturer  \
# 2            2MB1  Light Bomber                 Mitsubishi Heavy Industries
# 47         Battle  Light Bomber                             Fairey Aviation
# 60         Bre.19  Light Bomber  Socit des Ateliers d'Aviation Louis Brguet
# 96          Do 17  Light Bomber                       Dornier Flugzeugwerke
# 180          Ki-2  Light Bomber                 Mitsubishi Heavy Industries
# 184         Ki-30  Light Bomber                 Mitsubishi Heavy Industries
# 185         Ki-32  Light Bomber                   Kawasaki Heavy Industries
# 241      Mosquito  Light Bomber               de Havilland Aircraft Company
# 274  PZL.23 Karas  Light Bomber                  Pa?stwowe Zak?ady Lotnicze
# 289            SB  Light Bomber                       Tupolev Design Bureau
# 323     Wellesley  Light Bomber                          Vickers-Armstrongs
#
# ...

# %%
df["PrimaryRole"] == "Light Bomber"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# Name: PrimaryRole, Length: 338, dtype: bool

# %%
# Some 2 crew craft are bombers so. we will not attempt to make our own categories
df[(df["PrimaryRole"] == "Light Bomber") & (df["Crew"] == 2)]
# Out:
#              Name   PrimaryRole                                Manufacturer  \
# 2            2MB1  Light Bomber                 Mitsubishi Heavy Industries
# 60         Bre.19  Light Bomber  Socit des Ateliers d'Aviation Louis Brguet
# 184         Ki-30  Light Bomber                 Mitsubishi Heavy Industries
# 185         Ki-32  Light Bomber                   Kawasaki Heavy Industries
# 241      Mosquito  Light Bomber               de Havilland Aircraft Company
# 274  PZL.23 Karas  Light Bomber                  Pa?stwowe Zak?ady Lotnicze
#
#             Country  Number  ActiveSince  LastBuilt  Retired    State  Crew  \
# 2             Japan    48.0       1926.0        NaN   1931.0  Retired   2.0
# 60           France  2700.0       1924.0        NaN   1945.0  Retired   2.0
# 184           Japan   704.0       1938.0     1941.0   1945.0  Retired   2.0
# 185           Japan   854.0       1938.0     1940.0   1942.0  Retired   2.0
# ...

# %% [markdown]
# # Axis total and by country and type by country
# # Allies total num of type by country
# # compare with single bar chart in traditional blue and red colors

# %%
Axis_countries_plane_count = [] # Red Color - Germany, Italy, and Japan this 

Allies_country_plane_count = [] # Blue Color - 

powers = list(Aircraft_per_country.index)

# %%
Axis_countries = ['Japan',
                  'Germany',
                  'Italy']

Allies_countries = ['United States',
          'United Kingdom',
          'Russia',
          'France',
          'Poland',
          'Netherlands',
          'Australia',
          'China',
          'Czechoslovakia',
          'Romania']

# %% [markdown]
# ### the PZL.23 Karas was made in poland ans shown to be used against axis powers, even though poland was conquered , for this analasys we will asume country of manufacturer holds said countries primary alignment in wwii

# %%
Axis_countries
# Out:
# ['Japan', 'Germany', 'Italy']

# %%
jap_craft = df[df['Country'] == 'Japan'].groupby(['PrimaryRole']).count()

# %%
jap_craft['Number']
# Out:
# PrimaryRole
# Dive Bomber                 3
# Fighter                    16
# Ground Attack Aircraft      1
# Heavy Bomber                1
# Heavy Fighter               1
# Jet Fighter                 1
# Light Bomber                4
# Medium Bomber               8
# Night Fighter               1
# Other                       4
# Prototype Aircraft          2
# Reconnaissance Aircraft     7
# Seaplane                    6
# Torpedo Bomber              8
# Trainer Aircraft            2
# Transport                   4
# Name: Number, dtype: int64

# %%
jap_craft.T
# Out:
# PrimaryRole   Dive Bomber  Fighter  Ground Attack Aircraft  Heavy Bomber  \
# Name                    3       16                       1             1
# Manufacturer            3       16                       1             1
# Country                 3       16                       1             1
# Number                  3       16                       1             1
# ActiveSince             3       14                       1             1
# LastBuilt               3       15                       1             1
# Retired                 3       14                       1             1
# State                   3       16                       1             1
# Crew                    3       16                       1             1
# Length                  3       16                       1             1
# Wingspan                3       16                       1             1
# Height                  3       16                       1             1
# ...

# %%
Allies_countries
# Out:
# ['United States',
#  'United Kingdom',
#  'Russia',
#  'France',
#  'Poland',
#  'Netherlands',
#  'Australia',
#  'China',
#  'Czechoslovakia',
#  'Romania']

# %%
# CREATED new pd column with boolean value for Allies / Axis Powers
df['Allied_Powers'] = df['Country'].isin(Allies_countries)

# %% [markdown]
# # Optional way
# df['newColumn'] = df['oldColumn'].replace(['string1', 'string2','string3'], [True, False, True])

# %%
df[df['Country'].isin(Allies_countries)].groupby(['Country', 'PrimaryRole']).count()
# Out:
#                                         Name  Manufacturer  Number  \
# Country        PrimaryRole
# Australia      Fighter                     1             1       1
#                Other                       1             1       1
# China          Fighter                     1             1       1
#                Transport                   1             0       1
# Czechoslovakia Biplane Fighter             1             1       1
# ...                                      ...           ...     ...
# United States  Reconnaissance Aircraft     2             2       2
#                Seaplane                    9             9       9
#                Torpedo Bomber              3             3       3
#                Trainer Aircraft            2             2       2
#                Transport                   9             9       9
#
#                                         ActiveSince  LastBuilt  Retired  \
# Country        PrimaryRole
# ...

# %%
craft_type_total = df['PrimaryRole'].value_counts()
craft_type_total
# Out:
# Fighter                    76
# Medium Bomber              43
# Seaplane                   36
# Transport                  25
# Torpedo Bomber             18
# Reconnaissance Aircraft    16
# Prototype Aircraft         15
# Heavy Bomber               15
# Heavy Fighter              14
# Dive Bomber                11
# Light Bomber               11
# Trainer Aircraft           10
# Other                      10
# Ground Attack Aircraft      8
# Jet Fighter                 7
# Biplane Fighter             6
# Glider                      5
# Night Fighter               4
# Assault Drone               2
# Light Observation           2
# Sport Aircraft              1
# Liaison Aircraft            1
# Short-Haul Airliner         1
# Patrol Airship              1
# Name: PrimaryRole, dtype: int64

# %%
type(craft_type_total)
# Out:
# pandas.core.series.Series

# %%
# values attribute call values
craft_type_total.values
# Out:
# array([76, 43, 36, 25, 18, 16, 15, 15, 14, 11, 11, 10, 10,  8,  7,  6,  5,
#         4,  2,  2,  1,  1,  1,  1])

# %%
type(craft_type_total)
# Out:
# pandas.core.series.Series

# %%
# index attribute call the labels according to the values
craft_type_total.index
# Out:
# Index(['Fighter', 'Medium Bomber', 'Seaplane', 'Transport', 'Torpedo Bomber',
#        'Reconnaissance Aircraft', 'Prototype Aircraft', 'Heavy Bomber',
#        'Heavy Fighter', 'Dive Bomber', 'Light Bomber', 'Trainer Aircraft',
#        'Other', 'Ground Attack Aircraft', 'Jet Fighter', 'Biplane Fighter',
#        'Glider', 'Night Fighter', 'Assault Drone', 'Light Observation',
#        'Sport Aircraft', 'Liaison Aircraft', 'Short-Haul Airliner',
#        'Patrol Airship'],
#       dtype='object')

# %%
# This is a seaborn Plot
ax = sns.barplot(x=craft_type_total.values, y=craft_type_total.index, 
                 palette="Blues_d")

# %%
# Easy Default Pandas Plot
craft_type_total.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Easy Default Pandas Plot
craft_type_total.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### I find it Interesting there are more seaplanes are the 3rd largest Category
# ### than you generally see in movies , I could research this further

# %% [markdown]
# # What are the general caricteristics of the "Other Category"

# %%
other_craft_patterns = df['PrimaryRole'] == 'Other'
other_craft_patterns
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# Name: PrimaryRole, Length: 338, dtype: bool

# %% [markdown]
# # How to subset a dataset

# %%
other_craft_chars = ['Country','Crew','Length','Wingspan','Height','WingArea', 'MaxSpeed']

# %%
df2 = df[df['PrimaryRole'] == 'Other']
df2 = df2[other_craft_chars]
df2
# Out:
#             Country  Crew Length Wingspan  Height  WingArea  MaxSpeed
# 178           Japan   1.0   8.55      8.6   3.300     12.40     550.0
# 188           Japan   2.0      8     11.8   3.640     20.00     348.0
# 206           Japan   2.0    7.9    10.32   3.100     24.50     240.0
# 224  United Kingdom   2.0   8.99    11.89   2.820     21.80     356.0
# 244           Japan   1.0  6.066     5.12   1.160      6.00     648.0
# 246             NaN   NaN    NaN      NaN     NaN       NaN       NaN
# 272  United Kingdom   2.0   8.59    12.04   2.210     18.80     253.0
# 318          Russia   1.0   5.75      7.3   2.340      9.58     257.0
# 319          Russia   2.0   7.15     10.2   2.990     17.12     210.0
# 326       Australia   2.0   8.48    13.11   2.661     23.76     350.0

# %% [markdown]
# # Locate Specific Row

# %%
df.iloc[246]
# Out:
# Name                                N3N
# PrimaryRole                       Other
# Manufacturer     Naval Aircraft Factory
# Country                             NaN
# Number                              NaN
# ActiveSince                         NaN
# LastBuilt                           NaN
# Retired                             NaN
# State                               NaN
# Crew                                NaN
# Length                              NaN
# Wingspan                            NaN
# Height                              NaN
# WingArea                            NaN
# MaxSpeed                            NaN
# Allied_Powers                     False
# Name: 246, dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Removing NaN Values
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html#pandas-dataframe-dropna

# %%
# Remove all Entries where ['Country'] == NaN
df['Country'].dropna()
# Out:
# 1              France
# 2               Japan
# 3               Japan
# 4              France
# 5       United States
#             ...
# 333     United States
# 334    United Kingdom
# 335             Italy
# 336             Italy
# 337             Italy
# Name: Country, Length: 322, dtype: object

# %%
# Update Index to reflect changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          338 non-null    object
#  1   PrimaryRole   338 non-null    object
#  2   Manufacturer  337 non-null    object
#  3   Country       322 non-null    object
#  4   Number        321 non-null    float64
#  5   ActiveSince   310 non-null    float64
#  6   LastBuilt     270 non-null    float64
#  7   Retired       300 non-null    float64
#  8   State         322 non-null    object
#  9   Crew          322 non-null    float64
#  10  Length        320 non-null    object
#  11  Wingspan      321 non-null    object
#  12  Height        317 non-null    float64
#  13  WingArea      315 non-null    float64
#  14  MaxSpeed      322 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 39.7+ KB
